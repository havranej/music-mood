# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
arousal = pd.read_csv("../data/annotations/arousal_cont_average.csv", index_col = 0)
arousal
# Out:
#          sample_15000ms  sample_15500ms  sample_16000ms  sample_16500ms  \
# song_id
# 2             -0.109388       -0.114943       -0.116414       -0.118614
# 3             -0.110847       -0.123974       -0.131104       -0.135957
# 4              0.222328        0.179448        0.178389        0.184057
# 5             -0.255613       -0.251578       -0.251957       -0.251123
# 7              0.464233        0.460788        0.460990        0.461046
# ...                 ...             ...             ...             ...
# 995           -0.083658       -0.079965       -0.080614       -0.077533
# 996            0.340385        0.339627        0.340270        0.335955
# 997            0.367088        0.368839        0.352861        0.311679
# 999           -0.176851       -0.173603       -0.179410       -0.171693
# 1000           0.432808        0.434732        0.440664        0.446552
#
#          sample_17000ms  sample_17500ms  sample_18000ms  sample_18500ms  \
# song_id
# ...

# %%
arousal.hist("sample_15000ms")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff866333890>]],
#       dtype=object)

# %%
valence = pd.read_csv("../data/annotations/valence_cont_average.csv", index_col = 0)
valence.hist("sample_15000ms")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff866060690>]],
#       dtype=object)

# %%
annotations = pd.read_csv("../data/annotations/songs_info.csv", index_col = 0)
annotations.Genre = annotations.Genre.str.strip()
annotations.iloc[:,-1].hist()

# %%
annotations.Genre.hist()

# %%
sample_features = pd.read_csv("../data/default_features/2.csv", sep = ";")
sample_features
# Out:
#     frameTime  pcm_LOGenergy_sma_range  pcm_LOGenergy_sma_maxPos  \
# 0         0.0                31.741960                      29.0
# 1         0.5                 1.485820                      40.0
# 2         1.0                 1.683392                      49.0
# 3         1.5                 2.317858                      10.0
# 4         2.0                 2.337739                      44.0
# ..        ...                      ...                       ...
# 86       43.0                 1.577160                      37.0
# 87       43.5                 1.736333                      10.0
# 88       44.0                 2.099028                      21.0
# 89       44.5                 2.480069                      37.0
# 90       45.0                 1.038606                       0.0
#
#     pcm_LOGenergy_sma_minPos  pcm_LOGenergy_sma_maxameandist  \
# 0                        0.0                        4.398733
# ...
